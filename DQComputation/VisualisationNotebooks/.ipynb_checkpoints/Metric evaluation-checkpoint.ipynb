# %%
# %matplotlib notebook
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import matplotlib.patches as patches
from matplotlib.collections import PatchCollection
import pandas as pd
import math as m
import itertools
import os

# %%
models = ['logistic regression', 'knn', 'decision tree', 'random forest', 'ada boost', 'naive bayes', 'xgboost',
          'svc', 'gaussian process', 'mlp', 'sgd', 'gradient boosting']

# %% [markdown]
# # missing

# %%
iris_m_qa, iris_m_qf, _ = np.load("../Output/scores/iris_missing_(qa,qf,time).npy", allow_pickle=True)
cancer_m_qa, cancer_m_qf, _ = np.load("../Output/scores/cancer_missing_(qa,qf,time).npy", allow_pickle=True)
adult_m_qa, adult_m_qf, _ = np.load("../Output/scores/adult_missing_(qa,qf,time).npy", allow_pickle=True)

abalone_m_qa, abalone_m_qf, _ = np.load("../Output/scores/abalone_missing_(qa,qf,time).npy", allow_pickle=True)
statlog_m_qa, statlog_m_qf, _ = np.load("../Output/scores/statlog_missing_(qa,qf,time).npy", allow_pickle=True)
spambase_m_qa, spambase_m_qf, _ = np.load("../Output/scores/spambase_missing_(qa,qf,time).npy", allow_pickle=True)
heart_m_qa, heart_m_qf, _ = np.load("../Output/scores/heart_missing_(qa,qf,time).npy", allow_pickle=True)
bean_m_qa, bean_m_qf, _ = np.load("../Output/scores/bean_missing_(qa,qf,time).npy", allow_pickle=True)

# %%
ys = [0, 0.3, 0.6]
heights = [0.3, 0.3, 0.4]
colors = cm.rainbow([0.5, 0.75, 1])
zones = []

for j in range(3):
    zones.append(patches.Rectangle((0, ys[j]), 55, heights[j], color=colors[j], alpha=0.33))

fig, ax = plt.subplots()
x = np.array(range(0, 55, 5))

line1a, = plt.plot(x, iris_m_qa[0], color='C0')
line2a, = plt.plot(x, cancer_m_qa[0], color='C1')
line3a, = plt.plot(x, adult_m_qa[0], color='C2')

line1f, = plt.plot(x, iris_m_qf[0], '--', color='C0')
line2f, = plt.plot(x, cancer_m_qf[0], '--', color='C1')
line3f, = plt.plot(x, adult_m_qf[0], '--', color='C2')

plt.ylim([0, 1])
plt.xlim([0, 50])

ymajor_ticks = np.arange(0, 11, 1)/10
yminor_ticks = np.arange(0, 20, 1)/20
ax.set_yticks(ymajor_ticks)
ax.set_yticks(yminor_ticks, minor=True)
xmajor_ticks = np.arange(0, 51, 10)
xminor_ticks = np.arange(0, 50, 5)
ax.set_xticks(xmajor_ticks)
ax.set_xticks(xminor_ticks, minor=True)
ax.grid(which='minor', linestyle='--')
legend1 = plt.legend([line1a, line2a, line3a], ['Iris', 'Breast Cancer', 'Adult'])
plt.gca().add_artist(legend1)

pc = PatchCollection(zones, match_original=True)
ax.add_collection(pc)
plt.grid(alpha=0.5)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ys = [0, 0.3, 0.6]
heights = [0.3, 0.3, 0.4]
colors = cm.rainbow([0.5, 0.75, 1])
zones = []
for j in range(3):
    zones.append(patches.Rectangle((0, ys[j]), 55, heights[j], color=colors[j], alpha=0.33))

fig, ax = plt.subplots()
x = np.array(range(0, 55, 5))

line4a, = plt.plot(x, heart_m_qa[0], color='c')
line5a, = plt.plot(x, statlog_m_qa[0], color='m')
line6a, = plt.plot(x, abalone_m_qa[0], color='y')
line7a, = plt.plot(x, spambase_m_qa[0], color='k')
line8a, = plt.plot(x, bean_m_qa[0], color='0.5')

line4f, = plt.plot(x, heart_m_qf[0], '--', color='c')
line5f, = plt.plot(x, statlog_m_qf[0], '--', color='m')
line6f, = plt.plot(x, abalone_m_qf[0], '--', color='y')
line7f, = plt.plot(x, spambase_m_qf[0], '--', color='k')
line8f, = plt.plot(x, bean_m_qf[0], '--', color='0.5')

plt.ylim([0, 1])
plt.xlim([0, 50])

ymajor_ticks = np.arange(0, 11, 1)/10
yminor_ticks = np.arange(0, 20, 1)/20
ax.set_yticks(ymajor_ticks)
ax.set_yticks(yminor_ticks, minor=True)
xmajor_ticks = np.arange(0, 51, 10)
xminor_ticks = np.arange(0, 50, 5)
ax.set_xticks(xmajor_ticks)
ax.set_xticks(xminor_ticks, minor=True)
ax.grid(which='minor', linestyle='--')

legend1 = plt.legend([line4a, line5a, line6a, line7a, line8a], ['Heart Disease', 'Statlog', 'Abalone', 'Spambase', 'Dry Beans'])
plt.gca().add_artist(legend1)

pc = PatchCollection(zones, match_original=True)
ax.add_collection(pc)
plt.grid(alpha=0.5)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # outlier

# %%
iris_o_qa, iris_o_qf, _ = np.load("../Output/scores/iris_outlier_(qa,qf,time).npy", allow_pickle=True)
cancer_o_qa, cancer_o_qf, _ = np.load("../Output/scores/cancer_outlier_(qa,qf,time).npy", allow_pickle=True)
adult_o_qa, adult_o_qf, _ = np.load("../Output/scores/adult_outlier_(qa,qf,time).npy", allow_pickle=True)

abalone_o_qa, abalone_o_qf, _ = np.load("../Output/scores/abalone_outlier_(qa,qf,time).npy", allow_pickle=True)
statlog_o_qa, statlog_o_qf, _ = np.load("../Output/scores/statlog_outlier_(qa,qf,time).npy", allow_pickle=True)
spambase_o_qa, spambase_o_qf, _ = np.load("../Output/scores/spambase_outlier_(qa,qf,time).npy", allow_pickle=True)
heart_o_qa, heart_o_qf, _ = np.load("../Output/scores/heart_outlier_(qa,qf,time).npy", allow_pickle=True)
bean_o_qa, bean_o_qf, _ = np.load("../Output/scores/bean_outlier_(qa,qf,time).npy", allow_pickle=True)

# %%
ys = [0, 0.3, 0.6]
heights = [0.3, 0.3, 0.4]
colors = cm.rainbow([0.5, 0.75, 1])
zones = []

for j in range(3):
    zones.append(patches.Rectangle((0, ys[j]), 55, heights[j], color=colors[j], alpha=0.33))

fig, ax = plt.subplots()
x = np.array(range(0, 55, 5))

line1a, = plt.plot(x, iris_o_qa[0], color='C0')
line2a, = plt.plot(x, cancer_o_qa[0], color='C1')
line3a, = plt.plot(x, adult_o_qa[0], color='C2')

line1f, = plt.plot(x, iris_o_qf[0], '--', color='C0')
line2f, = plt.plot(x, cancer_o_qf[0], '--', color='C1')
line3f, = plt.plot(x, adult_o_qf[0], '--', color='C2')

plt.ylim([0, 1])
plt.xlim([0, 50])

ymajor_ticks = np.arange(0, 11, 1)/10
yminor_ticks = np.arange(0, 20, 1)/20
ax.set_yticks(ymajor_ticks)
ax.set_yticks(yminor_ticks, minor=True)
xmajor_ticks = np.arange(0, 51, 10)
xminor_ticks = np.arange(0, 50, 5)
ax.set_xticks(xmajor_ticks)
ax.set_xticks(xminor_ticks, minor=True)
ax.grid(which='minor', linestyle='--')

legend1 = plt.legend([line1a, line2a, line3a], ['Iris', 'Breast Cancer', 'Adult'])
plt.gca().add_artist(legend1)

pc = PatchCollection(zones, match_original=True)
ax.add_collection(pc)
plt.grid(alpha=0.5)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ys = [0, 0.3, 0.6]
heights = [0.3, 0.3, 0.4]
colors = cm.rainbow([0.5, 0.75, 1])
zones = []

for j in range(3):
    zones.append(patches.Rectangle((0, ys[j]), 55, heights[j], color=colors[j], alpha=0.33))

fig, ax = plt.subplots()
x = np.array(range(0, 55, 5))

line4a, = plt.plot(x, heart_o_qa[0], color='c')
line5a, = plt.plot(x, statlog_o_qa[0], color='m')
line6a, = plt.plot(x, abalone_o_qa[0], color='y')
line7a, = plt.plot(x, spambase_o_qa[0], color='k')
line8a, = plt.plot(x, bean_o_qa[0], color='0.5')

line4f, = plt.plot(x, heart_o_qf[0], '--', color='c')
line5f, = plt.plot(x, statlog_o_qf[0], '--', color='m')
line6f, = plt.plot(x, abalone_o_qf[0], '--', color='y')
line7f, = plt.plot(x, spambase_o_qf[0], '--', color='k')
line8f, = plt.plot(x, bean_o_qf[0], '--', color='0.5')

plt.ylim([0, 1])
plt.xlim([0, 50])

ymajor_ticks = np.arange(0, 11, 1)/10
yminor_ticks = np.arange(0, 20, 1)/20
ax.set_yticks(ymajor_ticks)
ax.set_yticks(yminor_ticks, minor=True)
xmajor_ticks = np.arange(0, 51, 10)
xminor_ticks = np.arange(0, 50, 5)
ax.set_xticks(xmajor_ticks)
ax.set_xticks(xminor_ticks, minor=True)
ax.grid(which='minor', linestyle='--')

legend1 = plt.legend([line4a, line5a, line6a, line7a, line8a], ['Heart Disease', 'Statlog', 'Abalone', 'Spambase', 'Dry Beans'])
plt.gca().add_artist(legend1)

pc = PatchCollection(zones, match_original=True)
ax.add_collection(pc)
plt.grid(alpha=0.5)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # fuzzing

# %%
iris_f_qa, iris_f_qf, _ = np.load("../Output/scores/iris_fuzzing_(qa,qf,time).npy", allow_pickle=True)
cancer_f_qa, cancer_f_qf, _ = np.load("../Output/scores/cancer_fuzzing_(qa,qf,time).npy", allow_pickle=True)
adult_f_qa, adult_f_qf, _ = np.load("../Output/scores/adult_fuzzing_(qa,qf,time).npy", allow_pickle=True)

abalone_f_qa, abalone_f_qf, _ = np.load("../Output/scores/abalone_fuzzing_(qa,qf,time).npy", allow_pickle=True)
statlog_f_qa, statlog_f_qf, _ = np.load("../Output/scores/statlog_fuzzing_(qa,qf,time).npy", allow_pickle=True)
spambase_f_qa, spambase_f_qf, _ = np.load("../Output/scores/spambase_fuzzing_(qa,qf,time).npy", allow_pickle=True)
heart_f_qa, heart_f_qf, _ = np.load("../Output/scores/heart_fuzzing_(qa,qf,time).npy", allow_pickle=True)

# %%
ys = [0, 0.3, 0.6]
heights = [0.3, 0.3, 0.4]
colors = cm.rainbow([0.5, 0.75, 1])
zones = []

for j in range(3):
    zones.append(patches.Rectangle((0, ys[j]), 55, heights[j], color=colors[j], alpha=0.33))

fig, ax = plt.subplots()
x = np.array(range(0, 55, 5))

line1a, = plt.plot(x, iris_f_qa[0], color='C0')
line2a, = plt.plot(x, cancer_f_qa[0], color='C1')
line3a, = plt.plot(x, adult_f_qa[0], color='C2')

line1f, = plt.plot(x, iris_f_qf[0], '--', color='C0')
line2f, = plt.plot(x, cancer_f_qf[0], '--', color='C1')
line3f, = plt.plot(x, adult_f_qf[0], '--', color='C2')

plt.ylim([0, 1])
plt.xlim([0, 50])

ymajor_ticks = np.arange(0, 11, 1)/10
yminor_ticks = np.arange(0, 20, 1)/20
ax.set_yticks(ymajor_ticks)
ax.set_yticks(yminor_ticks, minor=True)
xmajor_ticks = np.arange(0, 51, 10)
xminor_ticks = np.arange(0, 50, 5)
ax.set_xticks(xmajor_ticks)
ax.set_xticks(xminor_ticks, minor=True)
ax.grid(which='minor', linestyle='--')

legend1 = plt.legend([line1a, line2a, line3a], ['Iris', 'Breast Cancer', 'Adult'])
plt.gca().add_artist(legend1)

pc = PatchCollection(zones, match_original=True)
ax.add_collection(pc)
plt.grid(alpha=0.5)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ys = [0, 0.3, 0.6]
heights = [0.3, 0.3, 0.4]
colors = cm.rainbow([0.5, 0.75, 1])
zones = []

for j in range(3):
    zones.append(patches.Rectangle((0, ys[j]), 55, heights[j], color=colors[j], alpha=0.33))

fig, ax = plt.subplots()
x = np.array(range(0, 55, 5))

line4a, = plt.plot(x, heart_f_qa[0], color='c')
line5a, = plt.plot(x, statlog_f_qa[0], color='m')
line6a, = plt.plot(x, abalone_f_qa[0], color='y')
line7a, = plt.plot(x, spambase_f_qa[0], color='k')

line4f, = plt.plot(x, heart_f_qf[0], '--', color='c')
line5f, = plt.plot(x, statlog_f_qf[0], '--', color='m')
line6f, = plt.plot(x, abalone_f_qf[0], '--', color='y')
line7f, = plt.plot(x, spambase_f_qf[0], '--', color='k')

plt.ylim([0, 1])
plt.xlim([0, 50])

ymajor_ticks = np.arange(0, 11, 1)/10
yminor_ticks = np.arange(0, 20, 1)/20
ax.set_yticks(ymajor_ticks)
ax.set_yticks(yminor_ticks, minor=True)
xmajor_ticks = np.arange(0, 51, 10)
xminor_ticks = np.arange(0, 50, 5)
ax.set_xticks(xmajor_ticks)
ax.set_xticks(xminor_ticks, minor=True)
ax.grid(which='minor', linestyle='--')

legend1 = plt.legend([line4a, line5a, line6a, line7a, line8a], ['Heart Disease', 'Statlog', 'Abalone', 'Spambase', 'Dry Beans'])
plt.gca().add_artist(legend1)

pc = PatchCollection(zones, match_original=True)
ax.add_collection(pc)
plt.grid(alpha=0.5)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
